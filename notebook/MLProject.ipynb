# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import kagglehub
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.preprocessing import StandardScaler
#       3 from sklearn.linear_model import LogisticRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df = kagglehub.dataset_download("bobbyscience/league-of-legends-diamond-ranked-games-10-min")

features = ["blueTotalGold", "blueTotalExperience", "blueKills",
    "blueDeaths", "blueAvgLevel", "blueFirstBlood", "blueEliteMonsters",
    "blueTotalMinionsKilled", "blueGoldDiff", "blueExperienceDiff"]

print("Dataset shape:", df.shape)

X = df[features]
y = df["blueWins"]

print(f"Baseline features: {X}")
